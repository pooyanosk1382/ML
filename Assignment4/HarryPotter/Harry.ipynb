# %%
import spacy

# Load the English language model
nlp = spacy.load("en_core_web_sm")

# Read the contents of the text file
with open("01 Harry Potter and the Sorcerers Stone.txt", "r") as file:
    text = file.read()

# Process the text using the NER model
doc1 = nlp(text)

# Extract named entities
for entity in doc1.ents:
    print(f"Entity: {entity.text} - Entity Type: {entity.label_}")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In [2], line 4
#       1 import spacy
#       3 # Load the English language model
# ----> 4 nlp = spacy.load("en_core_web_sm")
#       6 # Read the contents of the text file
#       7 with open("01 Harry Potter and the Sorcerers Stone.txt", "r") as file:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\spacy\__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      27 def load(
#      28     name: Union[str, Path],
#      29     *,
#    (...)
#      34     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      35 ) -> Language:
#      36     """Load a spaCy model from an installed package or a local path.
#      37
#      38     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ...

# %%
import spacy

# Load the English language model
nlp = spacy.load("en_core_web_sm")

# Read the contents of the text file
with open("02 Harry Potter and the Chamber of Secrets.txt", "r") as file:
    text = file.read()

# Process the text using the NER model
doc2 = nlp(text)

# Extract named entities
for entity in doc2.ents:
    print(f"Entity: {entity.text} - Entity Type: {entity.label_}")

# %%
import spacy

# Load the English language model
nlp = spacy.load("en_core_web_sm")

# Read the contents of the text file
with open("03 Harry Potter and the Prisoner of Azkaban.txt", "r") as file:
    text = file.read()

# Process the text using the NER model
doc3 = nlp(text)

# Extract named entities
for entity in doc3.ents:
    print(f"Entity: {entity.text} - Entity Type: {entity.label_}")

# %%
import spacy

# Load the English language model
nlp = spacy.load("en_core_web_sm")

# Read the contents of the text file
with open("04 Harry Potter and the Goblet of Fire.txt", "r") as file:
    text = file.read()

# Process the text using the NER model
doc4 = nlp(text)

# Extract named entities
for entity in doc4.ents:
    print(f"Entity: {entity.text} - Entity Type: {entity.label_}")

# %%
import spacy

# Load the English language model
nlp = spacy.load("en_core_web_sm")

# Read the contents of the text file
with open("05 Harry Potter and the Order of the Phoenix.txt", "r") as file:
    text = file.read()

# Process the text using the NER model
doc5 = nlp(text)

# Extract named entities
for entity in doc5.ents:
    print(f"Entity: {entity.text} - Entity Type: {entity.label_}")

# %%
import spacy

# Load the English language model
nlp = spacy.load("en_core_web_sm")

# Read the contents of the text file
with open("06 Harry Potter and the Half-Blood Prince.txt", "r") as file:
    text = file.read()

# Process the text using the NER model
doc6 = nlp(text)

# Extract named entities
for entity in doc6.ents:
    print(f"Entity: {entity.text} - Entity Type: {entity.label_}")

# %%
import spacy

# Load the English language model
nlp = spacy.load("en_core_web_sm")

# Read the contents of the text file
with open("07 Harry Potter and the Deathly Hallows.txt", "r") as file:
    text = file.read()

# Process the text using the NER model
doc6 = nlp(text)

# Extract named entities
for entity in doc6.ents:
    print(f"Entity: {entity.text} - Entity Type: {entity.label_}")
